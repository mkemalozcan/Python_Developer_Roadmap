# %%
from IPython import display
display.Image(r"..\Data\life_cycle_of_a_function.png")

# %% [markdown]
# Unit tests automate the repetitive testing process and saves time.
#
# Python unit testing libraries
# - pytest
# - unittest
# - nosetests
# - docstest
#
# We will use pytest!
#
# - Has all essential features
# - Easiest to use
# - Most ppular

# %%
display.Image(r"..\Data\row_to_list_table.png")

# %% [markdown]
# > Assume that we have module "row_to_list.py"
#
# > Test module: "test_row_to_list.py"
#
# import pytest
#
# import row_to_list
#
# def test_for_clean_row():
#
#         assert row_to_list("2,081\t314,942\n) == ["2,081", "314,942"]
#
# def test_for_missing_area():
#
#         assert row_to_list("\t293,410\n") is None
#
# def test_for_missing_tab():
#
#         assert row_to_list("1,463238,765\n") is
#
# > Running unit tests
#
#         pytest test_row_to_list.py
#
# > Test result
#
#         F : Failure
#
#         . : Passed
#
#         > : The line raising the exception is marked by >
#
#         E : Contains the details about the exception

# %%
display.Image(r"..\Data\unit_test_failure.png")

# %% [markdown]
# > Mastering assert statements
#
#           assert boolean_expression, message

# %%
assert 1 == 2, " one is not equal to two!"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 assert 1 == 2, " one is not equal to two!"
#
# AssertionError:  one is not equal to two!

# %% [markdown]
# > Recommendations:
#
#         Include a message with assert statements.
#
#         Print values of any variable that is relevant to debugging.
#
#         Beware of float return values!

# %%
assert 0.1 + 0.1 + 0.1 == 0.3, "not equal"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 assert 0.1 + 0.1 + 0.1 == 0.3, "not equal"
#
# AssertionError: not equal

# %%
assert 0.1 + 0.1 + 0.1 == pytest.approx(0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 assert 0.1 + 0.1 + 0.1 == pytest.approx(0.3)
#
# NameError: name 'pytest' is not defined

# %%
# %%
# Out:
# Requirement already satisfied: pytest in c:\users\kemal\.conda\envs\my_env\lib\site-packages (7.1.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (22.1.0)
# Requirement already satisfied: iniconfig in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (22.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (1.4.0)
# Requirement already satisfied: colorama in c:\users\kemal\.conda\envs\my_env\lib\site-packages (from pytest) (0.4.6)
